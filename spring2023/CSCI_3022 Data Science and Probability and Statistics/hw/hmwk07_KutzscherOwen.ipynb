# %% [markdown]
# <a id='top'></a>
#
# # CSCI3022 S23
#
#
#
# # Homework 7: Joint Distributions
# ## Due Monday, March 20th at 11:59pm to Gradescope
# ***
#
# **Name**: _______Owen Kutzscher_________________________________________________________________
#
# ***
#
# ***
# ### Collaboration Policy
#
# While completing the assignment you are not allowed to consult any source other than the course textbooks/online reference links provided on Canvas, your own class notes, and/or the posted lecture slides/in-class Jupyter notebooks.   You may discuss questions you have with your classmates or on Piazza or in office hours, but all work you submit must be your own, which means when writing up your solutions or code, you MUST do it entirely by yourself.
#
# You should be able to easily reproduce from scratch and explain a solution that was your own when asked in office hours by a TA/Instructor or on a quiz/exam without referencing your notes/book/HW.
#
#
# **Do not search/ask for a solution online**: You may not actively search for a solution to the problems below from the internet. This includes posting to or using sources like ChatGPT, StackOverflow, StackExchange, Reddit, Chegg, CourseHero, etc.
#
# **We are here to help!  Visit HW Hours and/or post questions on Piazza!**
#
#
# Copying/consulting from the solution of another classmate or an online solution (or providing a classmate your solution) constitutes a **violation of the course's collaboration policy and the honor code and will result in an F in the course and a trip to the honor council**.
#
#
#
#
#
#
# ### Instructions for Submitting in Correct Format
#
# You must submit a PDF of this Juptyer notebook to Gradescope by the deadline listed above.  Submissions that are not a PDF or that are not submitted to Gradescope will not be counted for credit.
#
# $\color{red}{\text{Before submitting your PDF, make sure that your LaTeX has rendered correctly in your PDF.}}$
# $\color{red}{\text{Any of your solutions with incorrectly rendered or incompletely rendered LaTeX will be given 0 points.}}$
#
# - There are several ways to quickly make a .pdf out of this notebook for Gradescope submission.
#
#  - If you are running Juptyer locally on your computer:
#
#      - Option1 : Select Kernel->Restart & Run All.  Then select File ->  Print Preview, and then Right-Click -> Print using your default browser and "Print to PDF"
#
#      - Option 2: Select Kernel->Restart & Run All.   Then select File -> Download as PDF via LaTeX.  This will require your system path find a working install of a TeX compiler
#
#  - If you are running using CSEL:
#
#      - Option1 :  Go to File ->Save & Export Notebook As-> HTML.  Then open the HTML, and then Right-Click -> Print and select "Print to PDF".
#      - Option2 :  Go to File ->Download. Then use this converter https://htmtopdf.herokuapp.com/ipynbviewer/ to convert ipynb to pdf.
#
# ### Notes
# - For full points you must correctly match your questions to the respective Gradescope problem, and include clear comments in your code.   Please note that any LaTeX that is not correctly rendered in your submitted PDF will result in a 0 on the entire problem(s) that involves the unrendered LaTeX.
# - You **must show all work and justify ALL answers to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
# - Any relevant data sets are available on Canvas.
# - LaTeX Tips:  Here is a [reference guide] (https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference).  **All** of your written commentary, justifications and mathematical work should be in Markdown.  I also recommend the [wikibook](https://en.wikibooks.org/wiki/LaTeX) for LaTex.
# - Because you can technically evaluate notebook cells is a non-linear order, it's a good idea to do **Kernel $\rightarrow$ Restart & Run All** as a check before submitting your solutions.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.
#
# - There is *not a prescribed API* for these problems.  You may answer coding questions with whatever syntax or object typing you deem fit.  Your evaluation will primarily live in the clarity of how well you present your final results, so don't skip over any interpretations!  Your code should still be commented and readable to ensure you followed the given course algorithm.

# %%
import numpy as np
import math
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## (14 pts) Problem 1 :
#
#
# The following parts **are not related**:

# %% [markdown]
# **Part A)**: Use built-in Python functions to find the critical value $z_{0.05}$.  Then show graphically what this number represents in terms of the pdf of the standard normal distribution.

# %%
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
x = np.linspace(-4, 4, 1000)

plt.plot(x, stats.norm.pdf(x))

plt.fill_between(x, stats.norm.pdf(x, scale=1), where=[(x > 1.645) and (x < 4) for x in x], label='area is 0.05', alpha=0.4)

#label the 3rd quartile
labels=[0, 1.645]
my_xticks=[0,'$z_{0.05} = 1.645$']
plt.xticks(labels,my_xticks)
#choose where to position the legend
plt.legend(loc=(.6,.4), shadow=True)

# %% [markdown]
# **Part B)**   Let $X$ be a continuous random variable with a t-distribution with 2 degrees of freedom and let $Y$ be a continuous random variable with a t-distribution with 7 degrees of freedom.
#
#  - i).  Use built-in Python functions to graph the pdf $X$ and the pdf of $Y$ on the same graph along with the pdf of $Z$ (the standard normal distribution).  Label which pdf belongs to which Random Variable.

# %%
x = np.linspace(-4, 4, 1000)

plt.plot(x, stats.t.pdf(x,2))

plt.plot(x, stats.t.pdf(x,7))

plt.plot(x, stats.norm.pdf(x))

## HOW DO WE LABEL THE LINES?!?!

# %% [markdown]
# - ii).  What happens to the graph of the pdf of a t-distribution as the number of degrees of freedom increases?

# %% [markdown]
# **Solution**
#
# beginning at a numnber like say, 0.5, it first starts below the std normal plt. Then it jumps all the way up to the plt with 2 degrees of freedom, then back down to the std normal plt. As we increase the degrees of freedom from here it begins to approach the value with 2 degrees of freedom.

# %% [markdown]
#  - iii).  Calculate the following (using built-in Python functions) and then show graphically what each answer represents graphically in terms of the corresponding pdf (Recall:  $X$ is a continuous random variable with a t-distribution with 2 degrees of freedom
#     - a).   $P(X \leq 1.75)$

# %%
stats.t.cdf(1.75,2)
# Out:
# 0.888888888888889

# %%
x = np.linspace(-4, 4, 1000)

plt.plot(x, stats.t.pdf(x,2))

plt.fill_between(x, stats.t.pdf(x, 2), where=[(x > -4) and (x < 1.75) for x in x], label='area is 0.889', alpha=0.4)

#label the 3rd quartile
labels=[0, 1.75]
my_xticks=[0,'$1.75$']
plt.xticks(labels,my_xticks)
#choose where to position the legend
plt.legend(loc=(.6,.4), shadow=True)

# %% [markdown]
# - b).  The critical value $t_{0.05, 7}$

# %%
stats.t.ppf(0.95,7)
# Out:
# 1.894578605061305

# %%
x = np.linspace(-4, 4, 1000)

plt.plot(x, stats.t.pdf(x, 7))

plt.fill_between(x, stats.t.pdf(x, 7), where=[(x > 1.895) and (x < 4) for x in x], label='area is 0.05', alpha=0.4)

#label the 3rd quartile
labels=[0, 1.895]
my_xticks=[0,'$z_{0.05,7} = 1.895$']
plt.xticks(labels,my_xticks)
#choose where to position the legend
plt.legend(loc=(.6,.4), shadow=True)

# %% [markdown]
# **Part C)**.  Let $Y \sim F(5, 10)$, that is $Y$ is a continuous random variable with an F distribution with degrees of freedom d1=5 and d2=10.

# %% [markdown]
#  - i).  Calculate the following (using built-in Python functions) and then show graphically what each answer represents graphically in terms of the corresponding pdf.
#     - a).   $P(Y \leq 1.5)$

# %%
stats.f.cdf(1.5,5,10)
# Out:
# 0.72671348452423

# %%
x = np.linspace(0, 4, 1000)

plt.plot(x, stats.f.pdf(x, 5, 10))

plt.fill_between(x, stats.f.pdf(x, 5, 10), where=[(x > 0) and (x < 1.5) for x in x], label='area is 0.726', alpha=0.4)

#label the 3rd quartile
labels=[0, 1.5]
my_xticks=[0,'x=$1.5$']
plt.xticks(labels,my_xticks)
#choose where to position the legend
plt.legend(loc=(.6,.4), shadow=True)

# %% [markdown]
#  - b).  The critical value $F_{0.10, 5,10}$

# %%
stats.f.ppf(.9,5,10)
# Out:
# 2.521640686209624

# %%
x = np.linspace(0, 4, 1000)

plt.plot(x, stats.f.pdf(x, 5, 10))

plt.fill_between(x, stats.f.pdf(x, 5, 10), where=[(x > 2.522) and (x < 4) for x in x], label='area is 0.1', alpha=0.4)

#label the 3rd quartile
labels=[0, 2.522]
my_xticks=[0,'$x_{0.10, 5, 10}=2.522$']
plt.xticks(labels,my_xticks)
#choose where to position the legend
plt.legend(loc=(.6,.4), shadow=True)

# %% [markdown]
# **Part D)**.  Imagine that you sample 3 scores from a standard normal distribution, square each score, and sum the squares. What is the probability that the sum of these 3 squares will be 9 or higher?  (You can use built-in Python functions to calculate this probability).

# %% [markdown]
# $Y = Z_1^2+Z_2^2+Z_3^2 \implies Y \sim \chi^2(3)$
#
# Thus $P(Y \geq 9) $ is given by:

# %%
# sampling 3 so 3 degrees of freedom
# chi^2 fasho

1 - stats.chi2.cdf(9,3)
# Out:
# 0.029290886534888205

# %% [markdown]
# ***

# %% [markdown]
# ## (11 pts) Problem 2 :
#
# Suppose $X$ and $Y$ are two discrete random variables with the following joint probability mass function:
#
#
#
# $$
# \begin{array}{|c|c|c|}
# \hline
#  & Y=1 & Y=2 \\
# \hline
# X=1 & \frac{1}{3} & [\frac{1}{12}] \\
# \hline
# X=2 & \frac{1}{6} & 0  \\
# \hline
# X=4 & \frac{1}{12} & \frac{1}{3}  \\
# \hline
# \end{array}
# $$

# %% [markdown]
# **Part A)**
# What is $p_{X,Y}(1, 2)$ ?

# %% [markdown]
# **Solution**
#
# $1 - (\frac{1}{12} + \frac{2}{12} + \frac{4}{12} + \frac{4}{12} )= \frac{1}{12}$

# %% [markdown]
# **Part B)**
# Find the marginal PMF for X, (i.e. find $p_X(x)$).   Give your answer as a table.

# %% [markdown]
# **Solution**
# $
# \begin{array}{|c|c|c|}
# \hline
#  & p_x(x) \\
# \hline
# X=1 & \frac{5}{12} \\
# \hline
# X=2 & \frac{1}{6} \\
# \hline
# X=4 & \frac{5}{12}  \\
# \hline
# \end{array}
# $

# %% [markdown]
# **Part C)**
# Find the marginal PMF for Y.   Give your answer as a table.

# %% [markdown]
# **Solution**
# $
# \begin{array}{|c|c|c|}
# \hline
#  & Y=1 & Y=2 \\
# \hline
# p_y(y) & \frac{7}{12} & \frac{5}{12} \\
# \hline
# \end{array}
# $

# %% [markdown]
# **Part D)**
# Give the conditional probability table for $P(Y|X)$.

# %% [markdown]
# **Solution**
#
#
# $
# \begin{array}{|c|c|c|}
# \hline
#  & Y=1 | X & Y=2 | X \\
# \hline
# X=1 & \frac{4}{5} & \frac{1}{5} \\
# \hline
# X=2 & 1 & 0  \\
# \hline
# X=4 & \frac{1}{5} & \frac{4}{5}  \\
# \hline
# \end{array}
# $

# %% [markdown]
# **Part E)**
# Are $X$ and $Y$ independent?  Justify.

# %% [markdown]
# **Solution:**
#
# no
#
# $P(X=1)P(Y=1)$
#
# $\frac{5}{12}\frac{7}{12} = \frac{35}{144} \neq \frac{1}{3}$

# %% [markdown]
# ## (15 pts) Problem 3 :
#
# The following parts are not related:
#
#
# **Part A)**
# If Cov$(X,Y)=0$, what does this tell us about the random variables X and Y?

# %% [markdown]
# **Solution**
#
# There is no positive or negative linear relationship between the two variables X and Y.

# %% [markdown]
# **Part B)**  Given the following joint pmf for discrete random variables $X$ and $Y$:
#
# $$
# \begin{array}{|c|c|c|c|}
# \hline
#  & Y=0 & Y=1 & Y=2 \\
# \hline
# X=0 & \frac{1}{6} & \frac{1}{4} &\frac{1}{8} \\
# \hline
# X=1 & \frac{1}{8} & \frac{1}{6} &\frac{1}{6} \\
# \hline
# \end{array}
# $$
#
#
#  - i).  Calculate $Cov(X,Y)$.  Show your steps in LaTeX

# %% [markdown]
# **Solution to part (i)**:
#
# calculating this is way too much algebra :((((((((
#
#
# $Cov(X,Y) = E[XY] - E[X]E[Y]$
#
# $Cov(X,Y) = \frac{1}{2} - \frac{11}{24}(1)$
#
# $ = \frac{1}{24}$

# %% [markdown]
# - ii).  Calculate $\rho(X,Y)$   Show your steps in LaTeX

# %% [markdown]
# **Solution**
#
# $p(X,Y) = \frac{Cov(X,Y)}{\sigma_x \sigma_y}$
#
# $p(X,Y) = \frac{\frac{1}{24}}{\sqrt{\frac{143}{576}} \sqrt{\frac{7}{12}}}$
#
# $p(X,Y) \approx 0.11$

# %% [markdown]
# **Part C)**
# This part is NOT related to the parts above.
# Suppose you're only given the following information about two joint random variables $X$ and $Y$:
#
# $$\mu_X = 6, \hspace{2mm} \mu_Y = 5, \hspace{2mm} \sigma_X^2 = 4, \hspace{2mm} \sigma_Y^2=9 \text{ and }  E[XY]=27$$.
#
# For each of the quantities below, calculate if you have enough information, showing all steps.  If not, explain what additional info you'd need.
#
# i).  $Cov(X,Y)$
#
# ii).  $Cov(Y,X)$
#
# iii).  $\rho(X,Y)$
#
# iv).  $E[X+Y]$
#
# v). $Var[X+Y]$

# %% [markdown]
# **Solution**
#
# i)
#
# $Cov(X,Y) = E[XY] - \mu_x \mu_y$
#
# $Cov(X,Y) = 27 - 6* 5$
#
# $Cov(X,Y) = -3$
#
# ***
#
#
# ii)
#
# $Cov(Y,X) = Cov(X,Y)$
#
# $Cov(Y,X) = -3$
#
# ***
#
# iii)
#
# $p(X,Y) = \frac{Cov(X,Y)}{\sigma_x \sigma_y}$
#
# $p(X,Y) = \frac{-3}{2*3}$
#
# $p(X,Y) = \frac{-1}{2}$
# ***
#
# iv)
#
# $E[X+Y] = E[X] + E[Y]$
#
# $E[X+Y] = 6 + 5$
#
# $E[X+Y] = 11$
#
# ***
#
# v)
#
# $Var[X+Y] = Var[X] + Var[Y] + 2Cov(x,y)$
#
# $Var[X+Y] = (2 + 9) - 6$
#
# $Var[X+Y] = 7$

# %% [markdown]
# ## (10 pts) Problem 4 :
#
#
#
#
# **Part A**
#
# Give a real life example of 3 random variables, $X$, $Y$ and $Z$ such that $X$ and $Y$ are dependent, however $X$ and $Y$ are conditionally independent given $Z$.

# %% [markdown]
# **Solution**:
#
#
# X = Owen barley finishes the hw he needs to do
#
# Y = Owen goes skiing
#
# Z = Owen is extremily hungover

# %% [markdown]
# **Part B)**
# i). Let $T$, $V$ and $F$ be discrete joint random variables.
# Use the probability chain rule to write the joint probability $p_{T,V,F}(t,v,f)$ in terms of conditional probabilities.

# %% [markdown]
# **Solution**:
#
# $p_{T,V,F}(t,v,f) = p(t|v,f)p(v,f)$
#
# $p_{T,V,F}(t,v,f) = p(t|v,f)p(v|f)p(f)$

# %% [markdown]
# ii).  How does your answer to part (i) simplify if you are given additional information that $T$ and $V$ are conditionally independent given $F$?

# %% [markdown]
# **Solution**:
#
# $p(t|f)p(v|t)$

# %% [markdown]
# iii).  Now suppose you are given the following additional information about $T$, $V$ and $F$:
#
#  - $T$ is a discrete random variable that denotes whether or not you are tired (it takes on binary values such that
# 1 means tired, 0 means not tired).
#
#  - $V$ is a discrete random variable that denotes whether you have a fever ( 1 means fever, 0 means no fever).
#
#
#  - $F$ is a discrete random variable that denotes whether you have the flu (1 means flu, 0 means no flu).
#
#  - In general, $T$ and $V$ are NOT independent. However, we wil assume $T$ and $V$ ARE **conditionally independent** GIVEN $F$.
#
#  - Suppose you are given the following probabilities:
#
#   - $P(F = 1) = 0.1$
#
#   - $P(V=1|F=1) = 0.9$
#
#   - $P(V=1|F=0) = 0.05$
#
#   - $P(T=1|F=1) =  0.80$
#
#   - $P(T=1|F=0) =  0.60$
#
#
# Calculate $p_{T,V,F}(1,0,1)$

# %% [markdown]
# **Solution**:

# %% [markdown]
# **Part C**
#
# Let $A$, $B$ and $C$ be discrete joint binary random variables.
#
# You are given the following information:
#
#  - $B$ and $C$ are independent
#
#  - $P(B=1) =0.001 $
#
#  - $P(C=1) = 0.002 $
#
#  - The conditional probability table for $P(A=1|B,C)$ is given by:
#
#  $$
# \begin{array}{|c|c|c|}
# \hline
# B & C & P(A=1 \hspace{1mm} | \hspace{1mm}  B, C) \\
# \hline
# 1 & 1 & 0.95 \\
# \hline
# 1 & 0 & 0.94  \\
# \hline
# 0 & 1 & 0.29\\
# \hline
# 0 & 0 & 0.001  \\
# \hline
# \end{array}
# $$
#
#
# i).  What is $p_{A|B, C} (1|1,0)$?

# %% [markdown]
# **Solution**:

# %% [markdown]
# ii).  What is $p_{A|B, C} (0|1,0)$?

# %% [markdown]
# **Solution**:

# %% [markdown]
# iii).  What is $p_{A}(1)$?

# %% [markdown]
# **Solution**:

# %% [markdown]
# ## Final Answers To Selected Problems
#
# These are final answers for selected problems so you can check your work and determine if you are on the right track.  To receive credit on each problem you must show all steps leading to these answers, fully answer the problem, and justify your answer using correct mathematical notation.
# ***
#
#
# 1A). $z_{0.05} = 1.645$
#
# 1B(iii)(a).  $0.889$
#
# 1B(iii)(b).   $t_{0.05, 7}= 1.895$
#
# 1C(i)(a).  $0.7267$
#
# 1C(i)(b).  $F_{0.10, 5,10}=2.522 $
#
# 1D.   $0.029$
#
# 2E.  No - why?
#
# 3bi).  $\frac{1}{24}$
#
# 3bii). $ 2\sqrt{\frac{3}{1001}} \approx 0.11$
#
# 3Ci). $-3$
#
#
#
# 3Ciii).  $-\frac{1}{2}$
#
# 3Civ). $11$
#
# 3Cv).  $7$
#
# 4biii). $.008$
#
# 4cii).  $0.06$
#
# 4ciii). $.0025$
