# %%
# Problem 1: Apriori



products = ["Laptop", "Phone", "Headphones", "Charger", "Mouse", "Keyboard", "Monitor", "Tablet", "Smartwatch", "Speakers"]

# Fixed set of transactions for deterministic results
transactions = [
    ["Laptop", "Phone", "Charger"],
    ["Phone", "Headphones", "Charger", "Smartwatch"],
    ["Laptop", "Tablet", "Speakers"],
    ["Monitor", "Keyboard", "Mouse"],
    ["Laptop", "Monitor", "Keyboard", "Mouse"],
    ["Phone", "Smartwatch"],
    ["Headphones", "Charger"],
    ["Laptop", "Headphones", "Charger"],
    ["Monitor", "Tablet", "Speakers"],
    ["Laptop", "Phone", "Headphones", "Smartwatch"],
    ["Laptop", "Phone", "Mouse", "Keyboard"],
] * 91  # Repeat the fixed set 91 times to have 1001 transactions

# %%
# !pip install mlxtend

# %%
# 1. Use the Apriori algorithm to find all frequent
# itemsets with a minimum support threshold of 0.185.

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# first we will convert the data into something the apriori
# algorithems in mlxtend can work with
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#       Charger  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  \
# 0        True       False     False    True    False  False   True
# 1        True        True     False   False    False  False   True
# 2       False       False     False    True    False  False  False
# 3       False       False      True   False     True   True  False
# 4       False       False      True    True     True   True  False
# ...       ...         ...       ...     ...      ...    ...    ...
# 996      True        True     False   False    False  False  False
# 997      True        True     False    True    False  False  False
# 998     False       False     False   False     True  False  False
# 999     False        True     False    True    False  False   True
# 1000    False       False      True    True    False   True   True
#
#       Smartwatch  Speakers  Tablet
# 0          False     False   False
# 1           True     False   False
# 2          False      True    True
# ...

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.185, use_colnames=True)
frequent_itemsets
# Out:
#      support               itemsets
# 0   0.363636              (Charger)
# 1   0.363636           (Headphones)
# 2   0.272727             (Keyboard)
# 3   0.545455               (Laptop)
# 4   0.272727              (Monitor)
# 5   0.272727                (Mouse)
# 6   0.454545                (Phone)
# 7   0.272727           (Smartwatch)
# 8   0.272727  (Charger, Headphones)
# 9   0.272727      (Mouse, Keyboard)
# 10  0.272727        (Phone, Laptop)
# 11  0.272727    (Phone, Smartwatch)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
sorted_rules = rules.sort_values(by="lift", ascending=False)
top_5_rules = sorted_rules.head(5)
top_5_rules
# Out:
#     antecedents   consequents  antecedent support  consequent support  \
# 2       (Mouse)    (Keyboard)            0.272727            0.272727
# 3    (Keyboard)       (Mouse)            0.272727            0.272727
# 5       (Phone)  (Smartwatch)            0.454545            0.272727
# 6  (Smartwatch)       (Phone)            0.272727            0.454545
# 0     (Charger)  (Headphones)            0.363636            0.363636
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 2  0.272727        1.00  3.666667  0.198347         inf       1.000000
# 3  0.272727        1.00  3.666667  0.198347         inf       1.000000
# 5  0.272727        0.60  2.200000  0.148760    1.818182       1.000000
# 6  0.272727        1.00  2.200000  0.148760         inf       0.750000
# 0  0.272727        0.75  2.062500  0.140496    2.545455       0.809524

# %%
# Me trying to code all of apriori from scratch
# this is a nightmere, and so I stopped lmao





# # 1. Use the Apriori algorithm to find all frequent
# # itemsets with a minimum support threshold of 0.185.

# def apriori(itemsets_size_1, data, support_threshold):
#     k = 1
    
#     saved_itemsets = [[]]  # currently contains blank list for itemsets size k=0
#     saved_itemsets.append([])  # make blank list for itemsets size k=1
    
    
    
#     # fill saved_itemsets[1] with all itemset candidates with size k=1
#     for item in itemsets_size_1:
#         saved_itemsets[k].append([item])
#     print(saved_itemsets)
    
#     while len(saved_itemsets[k]) != 0:
#         # pruning step
#         temp_itemsets = []  # this will be used during Apriori...

#         # for size saved_itemsets[k]
#         # remove itemset if does not meet support_threshold
#         for itemset in saved_itemsets[k]:
#             # remove item if below support threshold
#             count = 0
#             for row in data:
#                 # check if the item is in the row
#                 # NOTE: no need to check for duplicates
#                 row_count = 0
#                 print("itemset: ", itemset)
                
#                 for item in itemset:
#                     print("item is: ", item)
#                     if item in row:
#                         row_count += 1
#                 if row_count == len(itemset):
#                     count = count + 1

#             item_support = count / len(data)
#             print(itemset, item_support)

#             if item_support >= support_threshold:
#                 temp_itemsets.append(itemset)

#         saved_itemsets[k] = temp_itemsets
#         print(saved_itemsets[k])

#         if len(saved_itemsets[k]) == 0:
#             break


#         k = k+1
#         saved_itemsets.append([])



#         # Apriori step
#         # this is not very effiecient :(
#         # but for the sake of this problem it'll do fine

#         for itemset1 in saved_itemsets[k-1]:
#             # temp_itemsets2.remove(item1)
#             for itemset2 in saved_itemsets[k-1]:
#                 if itemset2 <= itemset1:
#                     continue
#                 candidate_itemset = [itemset1, itemset2]
#                 saved_itemsets[k].append(candidate_itemset)
#         print(saved_itemsets[k]) 
    
    
    
    

    
# apriori(products, transactions, 0.185)
# Out:
# [[], [['Laptop'], ['Phone'], ['Headphones'], ['Charger'], ['Mouse'], ['Keyboard'], ['Monitor'], ['Tablet'], ['Smartwatch'], ['Speakers']]]
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# itemset:  ['Laptop']
# item is:  Laptop
# ...
