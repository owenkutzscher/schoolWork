# %% [markdown]
# <a id='top'></a>
#
# # CSCI3022 S23
#
#
#
# # Homework 1: Prerequisite Review; Intro to Jupyter & Data Cleaning
#
# ## Due Wed, January 25th at 11:59pm as a PDF submitted to Gradescope
# ***
#
# **Name**: _____Owen_Kutzscher________________________________
#
# ***
# ### Collaboration Policy
#
# While completing the assignment you are not allowed to consult any source other than the course textbooks/online reference links provided on Canvas, your own class notes, and/or the posted lecture slides/in-class Jupyter notebooks.   You may discuss questions you have with your classmates or on Piazza or in office hours, but all work you submit must be your own, which means when writing up your solutions or code, you MUST do it entirely by yourself.
#
# You should be able to easily reproduce from scratch and explain a solution that was your own when asked in office hours by a TA/Instructor or on a quiz/exam without referencing your notes/book/HW.
#
#
# **Do not search/ask for a solution online**: You may not actively search for a solution to the problems below from the internet. This includes posting to or using sources like ChatGPT, StackExchange, Reddit, Chegg, CourseHero, etc.
#
# **We are here to help!  Visit HW Hours and/or post questions on Piazza!**
#
#
# Copying/consulting from the solution of another classmate or an online solution (or providing a classmate your solution) constitutes a **violation of the course's collaboration policy and the honor code and will result in an F in the course and a trip to the honor council**.
#
#
#
#
#
#
# ### Instructions for Submitting in Correct Format
#
# You must submit a PDF of this Juptyer notebook to Gradescope by the deadline listed above.
# Your PDF should contain multiple pages (i.e. do NOT submit this entire notebook as one page).
# Submissions that are not a PDF or that are not submitted to Gradescope will not be counted for credit.
#
# $\color{red}{\text{Before submitting your PDF, make sure that your LaTeX has rendered correctly in your PDF.}}$
# $\color{red}{\text{Any of your solutions with incorrectly rendered or incompletely rendered LaTeX will be given 0 points.}}$
#
# - There are several ways to quickly make a .pdf out of this notebook for Gradescope submission.
#
#  - If you are running Juptyer locally on your computer:
#
#      - Option1 :  Use File ->  Print Preview, and then Right-Click -> Print using your default browser and "Print to PDF"
#
#      - Option 2: Use File -> Download as PDF via LaTeX.  This will require your system path find a working install of a TeX compiler
#
#  - If you are running using CSEL:
#
#      - Option1 :  Go to File ->Save & Export Notebook As-> HTML.  Then open the HTML, and then Right-Click -> Print and select "Print to PDF".
#      - Option2 :  Go to File ->Download. Then use this converter https://htmtopdf.herokuapp.com/ipynbviewer/ to convert ipynb to pdf.
#
# ### Notes
# - 46 points of this assignment are for the specific problems.  The remaining 4 are "Presentation Points."  This includes correctly matching your questions to the respective Gradescope problem, clear comments in your code, and neatness and thoroughness of your explanations.  Please note that any LaTeX that is not correctly rendered in your submitted PDF will result in a 0 on the entire problem(s) that involves the unrendered LaTeX.
# - For any question that asks you to calculate something, you **must show all work and justify your answers to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
# - Any relevant data sets are available on Canvas.
# - LaTeX Tips:  Here is a [reference guide] (https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference).  **All** of your written commentary, justifications and mathematical work should be in Markdown.  I also recommend the [wikibook](https://en.wikibooks.org/wiki/LaTeX) for LaTex.
# - Because you can technically evaluate notebook cells is a non-linear order, it's a good idea to do **Kernel $\rightarrow$ Restart & Run All** as a check before submitting your solutions.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.
#
# - There is *not a prescribed API* for these problems.  You may answer coding questions with whatever syntax or object typing you deem fit.  Your evaluation will primarily live in the clarity of how well you present your final results, so don't skip over any interpretations!  Your code should still be commented and readable to ensure you followed the given course algorithm.

# %% [markdown]
# $\color{red}{\text{Below is an example question to demonstrate the type of work and justification }}$
# $\color{red}{\text{that is required for full points when answering math questions using LaTex}}$.
# ## $\color{red}{\text{EXAMPLE QUESTION:}}  $
#
# Write a full solution to the following question using LaTex (i.e. do NOT use code to calculate the answer).
#
# What values of $x$ solve the equation: $\phantom{xx}x^2-5x=-6$?
#
# ### $\color{red}{\text{This correct answer would be worth zero points}}:$
#
# $x=2$ and $x=3$
#
# ### $\color{red}{\text{This answer would be worth full points}}:$
#
#
# Solution to Example Question:
#
# $x^2-5x=-6$
#
# $\implies x^2-5x+6=0$
#
# $\implies (x-2)(x-3)=0$
#
# $\implies \boxed{x=2}$ or $\boxed{x=3}$.

# %% [markdown]
# ## Problem 1:  (2 pts)
#     Create a markdown cell to introduce yourself.
#
#     It should contain:
#     a] A large print heading of your name
#     b] Some text about yourself
#     c] A hyperlink (link to whatever you'd like - this is to practice using hyperlinks)
#     d] A table (with whatever info you'd like to organize)
#     e] A picture (Note: pictures can be added either by dragging and dropping into the markdown cell, or via the menu by choosing 'edit', then 'insert image'. The image should be a jpeg).
#
#     It should look similar to the following cell:
#
#  ***

# %% [markdown]
# # Maribeth Oscamou
# CU Position: Associate Teaching Professor
#
# Link to our Canvas page: [Canvas](https://canvas.colorado.edu/courses/90459)
#
# My Top 3 Favorites | Ice Cream Flavors     | Places I've Traveled To
# --|:---------:|:-----------:
# 1|Cookie Dough     | Cinque Terre Italy
# 2|Mint Chocolate Chip   |Prague, Czech Republic
# 3|Cookies and Cream  |  Vienna, Austria
#
# My new puppy Bella:
#     ![Bella.jpg](attachment:Bella.jpg)

# %% [markdown]
# # Owen Kutzscher
# Computer science major from California
#
# Link to my current favorite music artist: [Boris Brejcha](https://youtu.be/1MobY_vR7-g?t=2441)
#
# Favorite things to do in: | Colorado | California
# --|:---------:|:-----------:
# 1|Ski | Hike
# 2|DJ | Play piano
# 3|Meet new people | See old friends
#
#
# My most recent song I made ![500 x 500.jpg](attachment:aa8cb823-ff30-4bfd-ab45-d38ab9e89232.jpg)

# %% [markdown]
# ## Problem 2 (3 pts):
#
#     Use Python to calculate the following.
#
#     a] What is 12 added to 3?
#
#     b] What is the remainder when 12 is divided by 5?
#
#     c] What is the integer result of 12 divided by 5?
#
#     d] What is the real number result of 12 divided by 5?
#
#     e] What is 12 to the 3rd power?
#
#     f] What is the square root of 15?
#
#
# ---

# %%
#Your Solution Here. 
import numpy as np  #numpy included for getting real number, and powers, roots



partA = 12 + 3

print("12 added to 3 is:", partA)



partB = 12 % 5

print("remainder when 12 is divided by 5 is:", partB)





partC = 12 // 5

print("integer result of 12 divided by 5 is:", partC)



partD = np.real(12 / 5)

print("real number result of 12 divided by 5 is:", partD)




partE = np.power(12, 3)

print("12 to the 3rd power is:", partE)




partF = np.sqrt(15)

print("square root of 15 is:", partF)
# Out:
# 12 added to 3 is: 15
# remainder when 12 is divided by 5 is: 2
# integer result of 12 divided by 5 is: 2
# real number result of 12 divided by 5 is: 2.4
# 12 to the 3rd power is: 1728
# square root of 15 is: 3.872983346207417

# %% [markdown]
# ## Problem 3: Calculus Review (15 pts):
# ### You will need a solid understanding of the following Calculus concepts to succeed in this course.  See the Prerequisite Review Resources posted on Canvas if you need to review any of these key concepts.
# ### Write full solutions to the following questions using LaTeX (i.e. do NOT use code to calculate the answer).  Fully explain all steps.  Simply writing an answer will be worth 0 points.
# $\color{red}{\text{Before submitting your PDF, make sure that your LaTeX has rendered correctly in your PDF.}}$
# $\color{red}{\text{Any questions in your final PDF with incorrectly rendered or incompletely rendered LaTeX will be given 0 points.}}$
#
# 3a) (3 pts). Consider the function $f(x)$ shown below.  It consists of two straight line segments and a semicircle.
#
# Evaluate $\int_0^6 f(x) \,dx$
#
#    ![2a_function.jpg](attachment:2a_function.jpg)

# %% [markdown]
# Your full solution here
#
# $\int_0^6 f(x) \,dx$
#
# $\implies \int_0^2 f(x) \,dx + \int_2^4 f(x) \,dx + \int_4^6 f(x) \,dx$
#
# $\implies (1\cdot2) + ((1\cdot2) + \frac{1}{2}\pi(1)^2) + \frac{1}{2}(1\cdot2)$
#
# $\implies 2 + (2+\frac{\pi}{2}) + 1$
#
# $\implies 5 + \frac{\pi}{2}$

# %% [markdown]
# ### 3b). (2 pts) Solve for $c$:
#
# $$\int_1^3 cx^2  \,dx = 1$$
#
# $\int_1^3 cx^2  \,dx = 1$
#
# $\implies \frac{c}{3} x^3|^3_{1} = 1$
#
# $\implies [\frac{c}{3}27]-[\frac{c}{3}] = 1$
#
# $\implies 27c-c=3$
#
# $\implies 26c = 3$
#
# $\implies c = \frac{3}{26}$

# %% [markdown]
# 3c). (1 pts) Evaluate   $$\frac{d}{d\lambda} \left( e^{-\lambda/4} \right) $$ Name any differentiation rules you use.

# %% [markdown]
# Your full solution here
# $\frac{d}{d\lambda} \left( e^{-\lambda/4} \right) $
#
# $\implies e^\frac{-\lambda}{4}(\frac{d}{dx}(\frac{-\lambda}{4}))$ ### differentiation-rule: $\frac{d}{dx}e^x = e^x (\frac{d}{dx}x)$
#
# $\implies e^\frac{-\lambda}{4}-\frac{1}{4}$

# %% [markdown]
# 3d). (3 pts) Does the following improper integral converge or diverge?  If it converges, find what it converges to.
#    For full credit you must use correct limit notation for handling improper integrals.
#    $$\int_{0}^{\infty} t \lambda e^{-\lambda t} \,dt$$.
#
#    (Hint: Recall $\int_{0}^{\infty} t \lambda e^{-\lambda t} \,dt = \lim\limits_{k \to \infty} \int_0^k t \lambda e^{-\lambda t} \,dt $).

# %% [markdown]
# Your full solution here
# ### I am not going to do this one  :/

# %% [markdown]
# 3e). (2 pts)  Let $$F(x)  = \int_{-1000}^x g(t) \,dt$$ where $g(t)$ is a real-valued, continuous function.  Do we have enough information to determine $F'(x)$?    If so, find it (and fully justify your answer).  If not, describe what additional information you'd need.

# %% [markdown]
# Your full solution here
#
# $F(x)  = \int_{-1000}^x g(t) \,dt$
#
# $\implies F'(x) = \frac{d}{dx} [\int g(x)]_{-1000}^{x}$
#
# $\implies F'(x) = \frac{d}{dx} [\int g(x) - \int g(-1000)]$
#
# $\implies F'(x) = g(x)$

# %% [markdown]
# 3f). (2 pts) Does the following series converge or diverge? Fully justify your answer.  If it converges, what does it converge to?
# $\sum_{n=1}^{\infty} (\frac{1}{4})^n$

# %% [markdown]
# Your full solution here
#
# $\sum_{n=1}^{\infty} (\frac{1}{4})^n$
#
# $\implies \sum_{n=0}^{\infty} (\frac{1}{4})^n      -     (\frac{1}{4})^0$
#
# $\implies \frac{1}{1-\frac{1}{4}} - 1$ ### formula $\sum_{n=0}^{\infty}ar^n = \frac{a}{1-r}$
#
# $\implies \frac{4}{3} - 1 $
#
# $\implies \frac{1}{3}$

# %% [markdown]
# 3g). (2 pts) Does the following series converge or diverge, given that $0<p<1$?  If it converges, what does it converge to?
#
# $\sum_{k=0}^{\infty} p(1-p)^k $

# %% [markdown]
# Your full solution here
#
# $\sum_{k=0}^{\infty} p(1-p)^k$
#
# $\implies \frac{p}{1-(1-p)}$  ### formula $\sum_{n=0}^{\infty}ar^n = \frac{a}{1-r}$
#
# $\implies \frac{p}{p}$
#
# $\implies 1$

# %% [markdown]
# ## Problem 4:  Discrete Structures Review (10 pts)
# ### You will need a solid understanding of the following concepts from Discrete Structures to succeed in this course. See the Prerequisite Review Resources posted on Canvas if you need to review any of these key concepts.
# ### Write full solutions to the following questions using LaTex (i.e. do NOT use code to calculate the answer).  Fully explain all steps.  Simply writing an answer will be worth 0 points.
#
#
# 4a). (2 pt) Parker, Danica, Madeleine and Colette line up at an ice cream truck.  How many different orders can they stand in? Justify your answer.

# %% [markdown]
# Your full solution here
#
#
# $P(4,4)$ ### 4 people total, no repeats, order matters, permutation
#
# $\implies \frac{4!}{(4-4)!}$
#
# $\implies \frac{4!}{1}$
#
# $\implies 24$

# %% [markdown]
# 4b). (2 pts) A coin is flipped 10 times.  How many possible outcomes have exactly 2 heads?  Fully justify your answer.

# %% [markdown]
# Your full solution here
#
# $\frac{n!}{n_1 ! n_2 ! ... n_k !}$ ### 8 indistinguishable elements type "heads" 2 indistinguishable elements type "tails"
#
# $\implies \frac{10!}{8!2!}$
#
# $\implies 45$

# %% [markdown]
# 4c). (3 pts)  What is the probability that if I roll two 6-sided dice they add up to **at most** $9$? Fully justify your answer.

# %% [markdown]
# Your full solution here
#
# $\frac{[outcomesAtMost9]}{[totalPossibleOutcomes]}$
#
# $\implies \frac{[totalPossibleOutcomes] - [outcomesGreaterThan9]}{[totalPossibleOutcomes]}$
#
# $[totalPossibleOutcomes]$
#
# $\implies [totalPossibleOutcomes] = \frac{6!}{(6-1)!} * \frac{6!}{(6-1)!}$ ### permutation P(6,1), 2 die
#
# $\implies [totalPossibleOutcomes] = 6 * 6$
#
# $\implies [totalPossibleOutcomes] = 36$
#
# $[outcomesGraterThan9]$
#
# $\implies [outcomesGraterThan9] = ((4,6),(5,5),(5,6),(6,4),(6,5),(6,6))$ ### all possible outcomes grater than 9 of the 2 die
#
# $\implies [outcomesGraterThan9] = 6$
#
# $\frac{[totalPossibleOutcomes] - [outcomesGreaterThan9]}{[totalPossibleOutcomes]}$
#
# $\implies \frac{[totalPossibleOutcomes] - [outcomesGreaterThan9]}{[totalPossibleOutcomes]} = \frac{36-6}{36}$
#
# $\implies \frac{[totalPossibleOutcomes] - [outcomesGreaterThan9]}{[totalPossibleOutcomes]} = \frac{5}{6}$

# %% [markdown]
# 4d). (3 pts)  Suppose you show up to a quiz completely unprepared.  The quiz has 10 questions, each with 5 multiple choice options. You decide to guess each answer in a completely random way.  What is the probability that you get exactly 3 questions correct?  You can leave your answer as a product of simplified fractions (you can leave exponents in your answers, but please do not leave any factorials or combination/permutation notation in your final answer).

# %% [markdown]
# Your full solution here
#
# We have 5 options for each choice, order matters for this count, and we want to see how many combonations of ways we can get 3 right
# To solve this problem we will use this forumla:
# $C(n,r)*(P(E))^r *(P(\neg E))^{n-r}$
#
# $n=10, r=3, E =$ probability getting a correct answer out of 5 options
#
# $\implies C(10,3)*(\frac{1}{5})^r *((\frac{4}{5})^{n-r})$
#
# $\implies (\frac{10!}{3!(10-3)!})*(\frac{1}{5^3}) *((\frac{4^7}{5^7})$
#
# $\implies (120)*(\frac{4^7}{5^{10}})$

# %% [markdown]
# ## Problem 5 (3 pts):
#
# Write a function that will take an integer x as an input, and as output will return either True or False depending whether or not the value of x is a multiple of 3.  Then test your function for the inputs x=13 and x=24.

# %%
def mult_of_3(x):
    #YOUR CODE HERE
    
    if x%3 == 0:
        return True
    else:
        return False
      
print("13 is a multiple of 3 is" ,mult_of_3(13))
print("24 is a multiple of 3 is", mult_of_3(24))
# Out:
# 13 is a multiple of 3 is False
# 24 is a multiple of 3 is True

# %% [markdown]
# Alternatively, to ensure your function is working correctly, run this small test.  Your function should return "True" for an input of 48.  If if doesn't, this will return a warning:

# %%
assert mult_of_3(48)==True, "Warning: Function Seems Broken"

# %% [markdown]
# # Problem 6:  Loading and Cleaning Data (13 pts)
# ***
#
# A sample survey of incoming college students (fresh out of high school) has been conducted on campus. Among the massive amounts of data collected we are going to look at just a few items and answer some questions concerning the sample.
#
# The data we want to work with is in the file, "frosh.csv".
#
# ***Description of the data set***
# This data was collected from a number of incoming freshman attending CU. The data was collected on move-in day as interviewers wandered through the crowds of people and spoke with new students that were willing to fill out a questionairre. The questionairre was administered and completed on a Saturday. The four pieces of data found in frosh.csv here are:
#
# '$\color{blue}{\text{height}}$' - This is the height of the student in inches. This data is intended to be rational numbers measured to the tenths place. When cleaning this data you might choose to consider the documentation for the Pandas .round function https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.round.html
#
# '$\color{blue}{\text{age}}$' - This is the age, in years, of the student in question; A18 refers to 'Age 18'. Once cleaned, this data should be integers.
#
# '$\color{blue}{\text{gender}}$' - This is the gender (sex) of the student. This data should be strings or characters of either 'M' or 'F'.
#
# '$\color{blue}{\text{lunch_money}}$' - This is the amount of money the student spent for lunch on the previous Friday.  Once cleaned, this data should be rational numbers measured to the hundredths place, thereby representing dollars and cents.
#
# '$\color{blue}{\text{ID}}$' - This is a 3 or 4 digit number used to identify each student. The datatype should be integer.

# %% [markdown]
# When analyzing data you will want to start with the following imports:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **a) (1 pt)** Load the data from the file "frosh.csv"

# %%
# To answer questions about the data set, load the data into a dataframe 'dfFrosh'.
# Load your data here:
dfFrosh = pd.read_csv("frosh.csv")

# %% [markdown]
# ***b) (1 pt)*** Look at the data and the datatypes in the file:

# %%
# Your solution here
# Answering questions about data neccesitates looking at the data to understand it.
# Look at your data and the datatypes here:
dfFrosh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1000 non-null   int64
#  1   height       1000 non-null   float64
#  2   age          1000 non-null   object
#  3   gender       997 non-null    object
#  4   lunch_money  1000 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 39.2+ KB

# %% [markdown]
# ***c) (1 pt)***
#  How many rows are in the data set?  (Below is a general format to use to print a sentence after you have calculated your answer).

# %%
total_rows = len(dfFrosh)

print("There are {} rows in the data set.".format(total_rows))
# Out:
# There are 1000 rows in the data set.

# %% [markdown]
# ***d) (1 pt)*** Delete any rows with missing data (NaN). How many rows were deleted?  (Use the same general format as provided in part (c) to print a sentence describing your answer.)

# %%
#Solution

dfFrosh = dfFrosh.dropna()

total_rows_2 = len(dfFrosh)

print("{} rows were deleted from the data set.".format(total_rows - total_rows_2))

dfFrosh.info()
# Out:
# 3 rows were deleted from the data set.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           997 non-null    int64
#  1   height       997 non-null    float64
#  2   age          997 non-null    object
#  3   gender       997 non-null    object
#  4   lunch_money  997 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 46.7+ KB

# %% [markdown]
# ***e)*** (5 pts) Clean ALL of the data to match the data type format and description of the data listed above, and take a look at the data again to see/show that it is in fact 'clean'.  Make sure to fully comment your code.

# %%
# Clean ALL the data to match the datatypes listed.  Your solution here:



#height
#This is the height of the student in inches.
#This data is intended to be rational numbers measured to the tenths place.
#When cleaning this data you might choose to consider the documentation for the Pandas.
#round function https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.round.html

dfFrosh.loc[:,"height"] = dfFrosh.loc[:,"height"].round(1)





#age
#This is the age, in years, of the student in question;
#A18 refers to 'Age 18'.
#Once cleaned, this data should be integers.

def fix_age(val):
    if(type(val) != int):
        if pd.isnull(val):
            return val

        stripped_val = val.strip()
        no_letters = stripped_val.replace("A","")
        return_val = int(no_letters)

        return return_val
    return val
     
    
    
    
dfFrosh.loc[:,"age"] = dfFrosh.loc[:,"age"].apply(fix_age)




#gender
#This is the gender (sex) of the student.
#This data should be strings or characters of either 'M' or 'F'.

def fix_gender(val):
    
    if type(val) == str:
        return val
    
    val = val.strip()
    val = str(val)
    return val

dfFrosh.loc[:,"gender"] = dfFrosh.loc[:,"gender"].apply(fix_gender)



#lunch_money
#This is the amount of money the student spent for lunch on the previous Friday.
#Once cleaned, this data should be rational numbers measured to the hundredths place, thereby representing dollars and cents.


def fix_lunch_money(val):
    
    if(type(val) == float):
        return val
    
    
    stripped_val = val.strip()
    
    stripped_val = stripped_val.replace('$','')
    stripped_val = float(stripped_val)
    stripped_val = round(stripped_val, 2)
    return stripped_val

dfFrosh.loc[:,"lunch_money"] = dfFrosh.loc[:,"lunch_money"].apply(fix_lunch_money)






#ID
#This is a 3 or 4 digit number used to identify each student.
#The datatype should be integer.

def fix_ID(val):
    
    if type(val) == int:
        return val
    
    val = val.strip()
    val = int(val)
    return val

dfFrosh.loc[:,"ID"] = dfFrosh.loc[:,"ID"].apply(fix_ID)
# Out:
# /tmp/ipykernel_198/3871018054.py:37: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfFrosh.loc[:,"age"] = dfFrosh.loc[:,"age"].apply(fix_age)
# /tmp/ipykernel_198/3871018054.py:77: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfFrosh.loc[:,"lunch_money"] = dfFrosh.loc[:,"lunch_money"].apply(fix_lunch_money)

# %%
# Take a look at the cleaned data.  Your solution here:


dfFrosh.info()
dfFrosh
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           997 non-null    int64
#  1   height       997 non-null    float64
#  2   age          997 non-null    int64
#  3   gender       997 non-null    object
#  4   lunch_money  997 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 46.7+ KB
#        ID  height  age gender  lunch_money
# 0     101    69.4   19      F        15.69
# 1     102    73.1   18      M         5.23
# 2     103    66.6   19      M        10.46
# 3     104    68.5   17      F        20.92
# 4     105    70.7   18      M        15.69
# ..    ...     ...  ...    ...          ...
# 995  1096    66.6   18      F        20.92
# 996  1097    65.4   19      F        47.07
# 997  1098    69.6   18      F        20.92
# 998  1099    62.8   17      F        36.61
# ...

# %% [markdown]
# f).(1 pt) How many 18-year olds are now in this data set? (Use the same general format as provided in part (c) to print a sentence describing your answer.)

# %%
#Your Solution

age_18 = dfFrosh.loc[(dfFrosh["age"] == 18)]
print("There are", len(age_18) , "18 year olds in the set.")
# Out:
# There are 474 18 year olds in the set.

# %% [markdown]
# g).  (1 pts)
#  What percentage of 18 year old males spent more than \$10 on lunch the previous Friday? (Use the same general format as provided in part (c) to print a sentence describing your answer.)

# %%
# Solution 

male_18_moreThan10 = age_18.loc[(age_18["gender"] == "M") & (age_18["lunch_money"] > 10)]
male_18 = age_18.loc[(age_18["gender"] == "M")]


print(round(len(male_18_moreThan10)*100/len(male_18),1), " % of males spend more than $10 on lunch money")
# Out:
# 67.3  % of males spend more than $10 on lunch money

# %% [markdown]
# h).(1 pt) Add a new column called 'height_f' to the dataframe that gives the respondents' height in feet.

# %%
# Solution 

def add_height_f(h):
    
    if pd.isnull(h):
        return h
    
    h_in_feet = h/12
    
    return h_in_feet


dfFrosh.loc[:,"height_f"] = dfFrosh.loc[:, "height"].apply(add_height_f)

# %% [markdown]
# i). (1 pt) How many feet tall is the shortest respondent?  (round your answer to the nearest hundredth of a foot)  (Use the same general format as provided in part (c) to print a sentence describing your answer.)

# %%
# Solution

dfFrosh.sort_values(by="height_f", ascending=False)

print("The shortest student is", round(dfFrosh.at[0,"height_f"], 2), "feet tall")
# Out:
# The shortest student is 5.78 feet tall

# %% [markdown]
# ## Final Answers To Selected Problems
#
# These are final answers for selected problems so you can check your work and determine if you are on the right track.  To receive credit on each problem you must show all steps leading to these answers, fully answer the problem, and justify your answer using correct mathematical notation.
#
#
# 3a).  $5+\frac{\pi}{2}$
#
# 3b). $c=\frac{3}{26}$
#
# 3d). Converges to $\frac{1}{\lambda}$
#
# 3e). $g(x)$  (why?!)
#
# 3f).  Converges to $\frac{1}{3}$
#
# 3g).  Converges to $1$.
#
# 4a).  $24$
#
# 4b).  $45$
#
# 4c).  $\frac{5}{6}$
#
# 4d). $(120)\left(\frac{4^7}{5^{10}}\right)$
#
# 6g). $67.3\%$
