# %%
### lets try to read data from a csv file!
# this really doesn't look too hard!

import pandas as pd
import csv

dataset = pd.read_csv("airlines.csv", nrows=100)

# %%
dataset.head()
# Out:
#    index  Airline ID                                          Name Alias IATA  \
# 0      0          -1                                       Unknown    \N    -
# 1      1           1                                Private flight    \N    -
# 2      2           2                                   135 Airways    \N  NaN
# 3      3           3                                 1Time Airline    \N   1T
# 4      4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN
#
#   ICAO Callsign         Country Active
# 0  NaN       \N              \N      Y
# 1  NaN      NaN             NaN      Y
# 2  GNL  GENERAL   United States      N
# 3  RNX  NEXTIME    South Africa      Y
# 4  WYT      NaN  United Kingdom      N

# %%
dataset.tail()
# Out:
#     index  Airline ID                        Name Alias IATA ICAO  \
# 95     95          95          Aerotrans Airlines    \N  NaN  AED
# 96     96          96             Aegean Airlines    \N   A3  AEE
# 97     97          97        Aerofumigaciones Sam    \N  NaN  AEG
# 98     98          98  Aeroexpreso Interamericano    \N  NaN  AEI
# 99     99          99                 Air Express    \N  NaN  AEJ
#
#             Callsign   Country Active
# 95               NaN    Russia      N
# 96            AEGEAN    Greece      Y
# 97  FUMIGACIONES SAM     Chile      N
# 98           INTERAM  Colombia      N
# 99     KHAKI EXPRESS  Tanzania      N
